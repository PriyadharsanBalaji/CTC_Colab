# %% [markdown]
# # Concept-to-Canvas (CTC) Colab Environment Setup
# This notebook automates the setup of the CTC pipeline on a Google Colab T4 GPU instance.

# %%
# 1. Install system dependencies for Manim
# !sudo apt update
# !sudo apt install -y texlive texlive-latex-extra texlive-fonts-extra texlive-latex-recommended texlive-science tipa libpango1.0-dev
# !sudo apt install -y libcairo2-dev ffmpeg

# %%
# 2. Install Python dependencies
# We install a pre-built wheel of llama-cpp-python with CUDA support to save time!\n
# !pip install llama-cpp-python --extra-index-url https://abetlen.github.io/llama-cpp-python/whl/cu121\n
# !pip install -r requirements.txt

# %%
# 3. Run the pipeline (Upload your PDF first to the Colab environment!)
# You can change 'sample.pdf' to your uploaded PDF filename.
# !python pipeline.py --pdf "sample.pdf"
